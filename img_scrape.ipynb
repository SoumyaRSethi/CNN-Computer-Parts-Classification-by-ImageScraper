# %%
import os
import time
import requests
from selenium import webdriver

# %%
# How to execute this code
# Step 1 : pip install selenium. pillow, requests
# Step 2 : make sure you have chrome installed on your machine
# Step 3 : Check your chrome version ( go to three dot then help then about google chrome )
# Step 4 : Download the same chrome driver from here  " https://chromedriver.storage.googleapis.com/index.html "
# Step 5 : put it inside the same folder of this code

# %%
def fetch_image_urls(query: str, max_links_to_fetch: int, wd: webdriver, sleep_between_interactions: int = 1):
    def scroll_to_end(wd):
        wd.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(sleep_between_interactions)

        # build the google query

    search_url = "https://www.google.com/search?safe=off&site=&tbm=isch&source=hp&q={q}&oq={q}&gs_l=img"

    # load the page
    wd.get(search_url.format(q=query))

    image_urls = set()
    image_count = 0
    results_start = 0
    while image_count < max_links_to_fetch:
        scroll_to_end(wd)

        # get all image thumbnail results
        thumbnail_results = wd.find_elements_by_css_selector("img.Q4LuWd")
        number_results = len(thumbnail_results)

        print(f"Found: {number_results} search results. Extracting links from {results_start}:{number_results}")

        for img in thumbnail_results[results_start:number_results]:
            # try to click every thumbnail such that we can get the real image behind it
            try:
                img.click()
                time.sleep(sleep_between_interactions)
            except Exception:
                continue

            # extract image urls
            actual_images = wd.find_elements_by_css_selector('img.n3VNCb')
            for actual_image in actual_images:
                if actual_image.get_attribute('src') and 'http' in actual_image.get_attribute('src'):
                    image_urls.add(actual_image.get_attribute('src'))

            image_count = len(image_urls)

            if len(image_urls) >= max_links_to_fetch:
                print(f"Found: {len(image_urls)} image links, done!")
                break
        else:
            print("Found:", len(image_urls), "image links, looking for more ...")
            time.sleep(30)
            return
            load_more_button = wd.find_element_by_css_selector(".mye4qd")
            if load_more_button:
                wd.execute_script("document.querySelector('.mye4qd').click();")

        # move the result startpoint further down
        results_start = len(thumbnail_results)

    return image_urls

# %%
def persist_image(folder_path:str,url:str, counter):
    try:
        image_content = requests.get(url).content

    except Exception as e:
        print(f"ERROR - Could not download {url} - {e}")

    try:
        f = open(os.path.join(folder_path, 'jpg' + "_" + str(counter) + ".jpg"), 'wb')
        f.write(image_content)
        f.close()
        print(f"SUCCESS - saved {url} - as {folder_path}")
    except Exception as e:
        print(f"ERROR - Could not save {url} - {e}")

# %%
def search_and_download(search_term: str, driver_path: str, target_path='./images', number_images=100):
    target_folder = os.path.join(target_path, '_'.join(search_term.lower().split(' '))) # make the folder name inside images with the search string

    if not os.path.exists(target_folder):
        os.makedirs(target_folder) # make directory using the target path if it doesn't exist already

    with webdriver.Chrome(executable_path=driver_path) as wd:
        res = fetch_image_urls(search_term, number_images, wd=wd, sleep_between_interactions=0.5)

    counter = 0
    for elem in res:
        persist_image(target_folder, elem, counter)
        counter += 1

# %%
DRIVER_PATH = './chromedriver'
search_term = 'Webcam'
# num of images you can pass it from here  by default it's 10 if you are not passing
# number_images = 10
search_and_download(search_term=search_term, driver_path=DRIVER_PATH) # method to download images
# Out:
# Found: 100 search results. Extracting links from 0:100
# Found: 101 image links, done!
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcTEVxCO6s3ErcLgMWBBo43yDeHWGA3cqtYvknGd2LweUARPq6sP&usqp=CAU - as ./images\webcam
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcTfK5OD6FJIp9TelSX_-1GSEFbVkyWw1tsWuV3grhN3S6oLnHFJ&usqp=CAU - as ./images\webcam
# SUCCESS - saved https://n4.sdlcdn.com/imgs/f/8/p/Intex-IT-306-30-MP-SDL961347939-1-9d2e4.png - as ./images\webcam
# SUCCESS - saved https://static.digit.in/default/thumb_23247_default_td_480x480.jpeg - as ./images\webcam
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQpooEqKuS_X0BY9KSE2GM-h0-hsRxuJlSl7UzsgGjxOcoSSdqM&usqp=CAU - as ./images\webcam
# SUCCESS - saved https://static.toiimg.com/photo/msid-75532466,resizemode-4/75532466.cms - as ./images\webcam
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcTn4t_J-ogGepaSD5c3K_7q32YUcJrVGehO0xBOe02RcaQSprh1&usqp=CAU - as ./images\webcam
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcSqP-axb5ztp690c2xyOdVp4PzYtCRnJGQ0XV6wi9xDq8yo0Kee&usqp=CAU - as ./images\webcam
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcRRfwULe1w57F5tG46dLGqysj7tOOih0-DIjaC8mW6ib0B0TUzV&usqp=CAU - as ./images\webcam
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcTu_99bzdjVs4jzSASUD2x5vQ7Jd6UNbxRu3HN4L6Yxiu3_HahU&usqp=CAU - as ./images\webcam
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQC9uSRQGlkVbY7pfYBQ5y6mkSPH4Rsm6DuhiwMTbAEA7l2PgTT&usqp=CAU - as ./images\webcam
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcTVHIHOsqcaA-JrnAih-06EvmS4XONPh-2XW-KslKKxLl_9gdz4&usqp=CAU - as ./images\webcam
# SUCCESS - saved https://cnet4.cbsistatic.com/img/TNZPbfDrR4vESMJef_dL9yU3l0Y=/940x0/2020/05/29/af33eefb-cb55-4e7b-ab62-04fbcf128bad/lenovo-500-fhd-webcam.jpg - as ./images\webcam
# SUCCESS - saved https://ae01.alicdn.com/kf/Ha12e9544d2d1439cac9289a0904f0299O/DeepFox-Webcam-USB-High-Definition-Camera-Web-Cam-360-Degree-MIC-Clip-on-For-Skype-Computer.jpg - as ./images\webcam
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQqdlhPGfGKk0gbLIABmZbJWA80wnb6GVJvDqP7lyZTx1hd1A_M&usqp=CAU - as ./images\webcam
# SUCCESS - saved https://sm.pcmag.com/t/pcmag_in/review/l/logitech-w/logitech-webcam-c600_4j9q.640.jpg - as ./images\webcam
# SUCCESS - saved https://i.ytimg.com/vi/gU4035dDN2s/maxresdefault.jpg - as ./images\webcam
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcRUMn3xM1amQ43sQufa1n4Qw-zk0DgxHk12VeFKbNwYVHrH8v_x&usqp=CAU - as ./images\webcam
# SUCCESS - saved https://images-na.ssl-images-amazon.com/images/I/71Ugc0JTYGL._SL1500_.jpg - as ./images\webcam
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcT0LEHGErsjPsDueQ0MWF8He-k1OXlMeEXWMkdq_VqDyeqp5SIA&usqp=CAU - as ./images\webcam
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcRQt8UD-SV41PeY21gwRw5PI6G3I0XN22Dj8LUGuzXM0lVzimHY&usqp=CAU - as ./images\webcam
# SUCCESS - saved https://aws.robu.in/wp-content/uploads/2017/12/New.jpg - as ./images\webcam
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcRc707rwvFZM9pjsAOP8WJBQywr6Xxc2CXauHkyw0ET2uWcJFsm&usqp=CAU - as ./images\webcam
# SUCCESS - saved https://specials-images.forbesimg.com/imageserve/5e8b369901879f000703e1ea/960x0.jpg?fit=scale - as ./images\webcam
# SUCCESS - saved https://images-na.ssl-images-amazon.com/images/I/41llJfjkkgL._SY450_.jpg - as ./images\webcam
# SUCCESS - saved https://5.imimg.com/data5/MD/QL/MY-14158318/logitech-webcam-500x500.jpg - as ./images\webcam
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcS1G01ON-MOrv8cxTl2isoFzCYUlIsETWhMvwX4j54ACTmfTfts&usqp=CAU - as ./images\webcam
# SUCCESS - saved https://2.imimg.com/data2/BD/GM/MY-2839722/computer-webcam-500x500.jpg - as ./images\webcam
# SUCCESS - saved https://assets.logitech.com/assets/65478/c920-pro-hd-webcam-refresh.png - as ./images\webcam
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcRA4jJ7ykVhNChRN1cUqdccOnv4CxfsuARQBQtcoky9g8C6IBOb&usqp=CAU - as ./images\webcam
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQ2nXONf4deWWRbD5w4IkXmRYxCkE2UK2mwoXZ9O5xJlyRyEGqF&usqp=CAU - as ./images\webcam
# SUCCESS - saved https://media.wired.com/photos/5eab69503c53cd00c2678764/master/pass/Gear-Web-Phone-Cam-959082912.jpg - as ./images\webcam
# SUCCESS - saved https://qph.fs.quoracdn.net/main-qimg-b313cfe454d3fb8d07266d585f6c386c.webp - as ./images\webcam
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcRwE0Gb6_H7nYcFsgm0vqN9ieSrdiPEPRv6KXE2G8URl9Wwpu4E&usqp=CAU - as ./images\webcam
# SUCCESS - saved https://assets.logitech.com/assets/65480/2/c270-hd-webcam-refresh.png - as ./images\webcam
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcRQy0NsPlPSx2Q7dwhILg2O507h53IQJDRlfigXyTvYl_bcXN0F&usqp=CAU - as ./images\webcam
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcRqiTyMPEkzl13NP5KTq6IFKJCUVcmbvLFhCZo8wC_UQet2ZaHe&usqp=CAU - as ./images\webcam
# SUCCESS - saved https://www.helpingindia.com/images/quantum-495lm.png - as ./images\webcam
# SUCCESS - saved https://www.androidguys.com/wp-content/uploads/2020/04/skype-meetings.jpg - as ./images\webcam
# SUCCESS - saved https://assets.croma.com/medias/sys_master/images/images/h3a/h3b/8797049061406/167187_pjpeg.jpg - as ./images\webcam
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQVnZ6HF10-_lQCDw8Ki6yNGgICCjInFoDsqnqtcenaLuAf8GcO&usqp=CAU - as ./images\webcam
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcSEGkfS0PnY4dCR5pF-MLuJWp6GEtSMvfivnPkUyGonrWT_Oh_F&usqp=CAU - as ./images\webcam
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcTCchv8ITpFYZiMaGzPOvr9TJKZ5zHZ9nnOlp5I06UTR_vCnjMd&usqp=CAU - as ./images\webcam
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcRZNEV2rIMHvSUVKp6i5r1p-dl4Ydgdm2Ls5mVSBDru-6dSTrEw&usqp=CAU - as ./images\webcam
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQfCP0WFjHOpbR3j9kUOBnHpXUn5KCqcy1hog4NDrBe1o-DVDRj&usqp=CAU - as ./images\webcam
# SUCCESS - saved https://cdn.shopify.com/s/files/1/1169/2482/products/Logitech_C925e_HD_webcam_with_1080p_video_Webcam-image_3_700x700.jpg?v=1588033606 - as ./images\webcam
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcRpyaqAochtkn0jUP4Bm-m4u7oX5878SeNT4bmAeZjCBknevzJj&usqp=CAU - as ./images\webcam
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcSJkZQvef_sfT054Pm3CCL1mql5O9GLlGF6ZotQzzKUAV521-um&usqp=CAU - as ./images\webcam
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcS_lAlXTIH1S2TM-_ArGm-YJorFvPxtRdJ8N2mvIDD9SOFuFfu3&usqp=CAU - as ./images\webcam
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcRJ6AEYNMAdaNGC3AX8XkY9Wdc-6WWCsAXBgeL9lfnKtRwLsiuT&usqp=CAU - as ./images\webcam
# SUCCESS - saved https://assetscdn1.paytm.com/images/catalog/product/C/CO/COMQUICK-1-3MP-STEL1153764DE3D4592/0..JPEG?imwidth=282&impolicy=hq - as ./images\webcam
# SUCCESS - saved https://cdn.mos.cms.futurecdn.net/VHoQNnQB9xdbADvejEWXzF-320-80.jpg - as ./images\webcam
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcTSGt8Df-Al6QCWREPkqmEMfZiYrkhj13xDU6yuvV_HONjjrYXq&usqp=CAU - as ./images\webcam
# SUCCESS - saved https://vlebazaar.in/image/cache/catalog//B00L5AWKUM/Quantum-QHM495LM-6-Light-Webcam-For-LaptopDesktop-Black-B00L5AWKUM-2-550x550.jpg - as ./images\webcam
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcTzs-mjHLuW1NbZ_ouMgbJYBkOTPxtdCJ8RLJOeSlA6X3olSdSb&usqp=CAU - as ./images\webcam
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcTFRCURUYaWJXiwH88kufk_3sixzOoSAWGLosEEbBBG1_7Hh5Bv&usqp=CAU - as ./images\webcam
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcSx_CMoFWYCAqtwWK0hFNcb1A1OQnMksbfwo9mUxoPI6orByAXH&usqp=CAU - as ./images\webcam
# SUCCESS - saved https://rukminim1.flixcart.com/image/612/612/kb89ea80/webcam/f/k/d/logitech-b525-commercial-hd-webcam-960-000841-original-imafsme97fzzwr4a.jpeg?q=70 - as ./images\webcam
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQ2ftVHoXpXk_OWWeW_uyRpJxudsrtrgj_YLehQScZ3NVrllgwU&usqp=CAU - as ./images\webcam
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcSGu9FyCfNqSSGdD9iUg9_CR9ZA8N7a1-94nsQXPRLpyW6o3G4j&usqp=CAU - as ./images\webcam
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcS7ezJfwRfvOLr2Z_eLtPb7K03_FxkE5Po9LMwY909-1UGpFohw&usqp=CAU - as ./images\webcam
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcRG-jNpHaGyuMW6g88JwlZDR4qygyQ3fUVnzRXVpVn-fzK6Tmvg&usqp=CAU - as ./images\webcam
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcT7-GfIjyE7uBnRmmvMKhWalAduGl3DvFPnzFl6GyweahS3QIAK&usqp=CAU - as ./images\webcam
# SUCCESS - saved https://images-eu.ssl-images-amazon.com/images/I/71CLwDI4hiL._AC._SR360,460.jpg - as ./images\webcam
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcR3I-SmF9IzA-ONeYT2oRSLqh9Ao0pCAmApypLiBCwmc8ZSlNGW&usqp=CAU - as ./images\webcam
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcRiqssA9ybAO4aKgJsqs0kqcdv1wU0fLFPFUvipQzeHVM4LfK3M&usqp=CAU - as ./images\webcam
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcTNQe_gHpS52hgZ8fO0oNACLcGAnXU4suFhzw-DFqZE2FXS6ydY&usqp=CAU - as ./images\webcam
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcTWySs4ALMD17wCpJ5uID0oJJsGJi2zyi9RrxSPucMlHFiBP0Nc&usqp=CAU - as ./images\webcam
# SUCCESS - saved https://beebom.com/wp-content/uploads/2018/02/The-10-Best-Webcam-Software.jpg - as ./images\webcam
# SUCCESS - saved https://www.dhresource.com/0x0/f2/albu/g4/M01/3A/81/rBVaEFm36k6AOFvkAAEGL448IkM511.jpg - as ./images\webcam
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcSrSw771v13NPI4X3BRVAbymFqI76HJDXFvR6N09B9aEonk_6e7&usqp=CAU - as ./images\webcam
# SUCCESS - saved https://cdn.mos.cms.futurecdn.net/tLqdpWAAo9vYncH8a5tfeM.jpg - as ./images\webcam
# SUCCESS - saved https://cdn.shopify.com/s/files/1/1169/2482/products/Logitech_BRIO_4K_Ultra_HD_Webcam_1800x1800.jpg?v=1579567653 - as ./images\webcam
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcSyiHsOAPUknksv-kZRsnlcg9nhvtFP0oanECwvxGuLaK4IV6x9&usqp=CAU - as ./images\webcam
# SUCCESS - saved https://rukminim1.flixcart.com/image/612/612/kay9bbk0/webcam/h/h/z/srihome-sh003-2mp-full-hd-1080p-webcam-for-pc-laptop-desktop-original-imafservhzx4yq89.jpeg?q=70 - as ./images\webcam
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQsFt49FSNLSUMIq_DazGIxA_PtlpDAZRRVyGHH6_bSHv_MGErz&usqp=CAU - as ./images\webcam
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQ8N8OObuYZm5WB_E3i3i6_fFCO879nzm9IFN2CbpLKXcoCQcXS&usqp=CAU - as ./images\webcam
# SUCCESS - saved https://cdn4.explainthatstuff.com/microsoft-lifecam-webcam.jpg - as ./images\webcam
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcT7fIcTb1oKzaDTSz7YeFDidknrNCjYElcsDtpeWgJbq1hkpCh_&usqp=CAU - as ./images\webcam
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcTQljp2XeZWuoQWiZB7fvXfA2s913BblUMqPHj50jtQ3t1sd8Nk&usqp=CAU - as ./images\webcam
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcTjvjEjmyK7qcKoz9MLjgIHUraYv5imgZzUNhjmpltWLX541og6&usqp=CAU - as ./images\webcam
# SUCCESS - saved https://nakedsecurity.sophos.com/wp-content/uploads/sites/2/2020/03/shutterstock_162788069-compressor.jpg?w=780&h=408&crop=1 - as ./images\webcam
# SUCCESS - saved https://assets.logitech.com/assets/65382/2/b525-pdp-2017-refresh.png - as ./images\webcam
# SUCCESS - saved https://ae01.alicdn.com/kf/HTB1rLllXtjvK1RjSspiq6AEqXXaz/Webcam-1080P-HDWeb-Camera-with-Built-in-HD-Microphone-1920-x-1080p-USB-Plug-n-Play.jpg - as ./images\webcam
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcRXdr-jEb_2A6In4HtR24DOQlniONut5HC7iQLuIar5KY9RJPZp&usqp=CAU - as ./images\webcam
# SUCCESS - saved https://4.imimg.com/data4/MU/GA/MY-2993257/dell-webcam-500x500.jpg - as ./images\webcam
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQi3jUwTzcZtP4ZEqFKTEPaJKRtormzgoqjOxv7OHoEktzzjcfT&usqp=CAU - as ./images\webcam
# SUCCESS - saved https://5.imimg.com/data5/TM/FP/OG/SELLER-20283976/rectangle-webcam-cover-for-laptops-pad-devices-500x500.jpg - as ./images\webcam
# SUCCESS - saved https://ae01.alicdn.com/kf/H538e43f42b5a46ea82a5d409107f84ecv/HXSJ-S1-Web-Camera-HD-1080P-Webcam-Built-in-Microphone-Auto-Focus-High-end-Video-Call.jpg_q50.jpg - as ./images\webcam
# SUCCESS - saved https://images.philips.com/is/image/PhilipsConsumer/SPC530NC_00-IMS-en_IN?$jpglarge$&wid=960 - as ./images\webcam
# SUCCESS - saved https://sm.pcmag.com/t/pcmag_in/review/l/logitech-w/logitech-webcam-c930e_njkc.1024.jpg - as ./images\webcam
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcRZU9ht59fETRcT4ZHMGw6decOUDLN_YsPmSzxbPSj2l6NmaW9I&usqp=CAU - as ./images\webcam
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQamYKsiKkgPjqnj6FLL4TMxV_EMQbSACJltfyrFLUugKkcWTvU&usqp=CAU - as ./images\webcam
# SUCCESS - saved https://static.bhphoto.com/images/images750x750/1586267213_843688.jpg - as ./images\webcam
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQpJAqV7oekiqM3x6yULe52GTU0y5gdOU901V7GztaExxIXaHJW&usqp=CAU - as ./images\webcam
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcTdUf4-mDS7iLcMFlAftXfGNVSrwczcN5Aag8oehgeQjtSxs3d5&usqp=CAU - as ./images\webcam
# SUCCESS - saved https://snpi.dell.com/snp/images/products/large/en-us~f849da04-1d3d-4b26-9857-4cab6f6e7aaf/f849da04-1d3d-4b26-9857-4cab6f6e7aaf.jpg - as ./images\webcam
# SUCCESS - saved https://images-na.ssl-images-amazon.com/images/I/71S3%2BcXOBCL._SX466_.jpg - as ./images\webcam
# SUCCESS - saved https://static.toiimg.com/thumb/msid-74668882,width-1070,height-580,imgsize-1133292,resizemode-75,overlay-toi_sw,pt-32,y_pad-40/photo.jpg - as ./images\webcam
# SUCCESS - saved https://i.ytimg.com/vi/2eh-8wUgifo/maxresdefault.jpg - as ./images\webcam
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcS7hV380glhqrH5KYKZ5lwdP85fVBx6jMA8Om2XUuf3kHFGB0HR&usqp=CAU - as ./images\webcam
